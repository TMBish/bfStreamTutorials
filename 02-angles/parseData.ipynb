# %%
import pandas as pd
import numpy as np
import requests
import os
import re
import tarfile
import zipfile
import bz2
import glob
import logging
import yaml

from datetime import date, timedelta
from unittest.mock import patch
from typing import List, Set, Dict, Tuple, Optional
from itertools import zip_longest
import betfairlightweight
from betfairlightweight import StreamListener
from betfairlightweight.resources.bettingresources import (
    PriceSize,
    MarketBook
)

# Utility Functions
# _________________________________

def as_str(v) -> str:
    return '%.2f' % v if type(v) is float else v if type(v) is str else ''

def split_anz_horse_market_name(market_name: str) -> (str, str, str):
    parts = market_name.split(' ')
    race_no = parts[0] # return example R6
    race_len = parts[1] # return example 1400m
    race_type = parts[2].lower() # return example grp1, trot, pace
    return (race_no, race_len, race_type)

def filter_market(market: MarketBook) -> bool: 
    d = market.market_definition
    return (d.country_code == 'AU' 
        and d.market_type == 'WIN' 
        and (c := split_anz_horse_market_name(d.name)[2]) != 'trot' and c != 'pace')

def load_markets(file_paths):
    for file_path in file_paths:
        print(file_path)
        if os.path.isdir(file_path):
            for path in glob.iglob(file_path + '**/**/*.bz2', recursive=True):
                f = bz2.BZ2File(path, 'rb')
                yield f
                f.close()
        elif os.path.isfile(file_path):
            ext = os.path.splitext(file_path)[1]
            # iterate through a tar archive
            if ext == '.tar':
                with tarfile.TarFile(file_path) as archive:
                    for file in archive:
                        yield bz2.open(archive.extractfile(file))
            # or a zip archive
            elif ext == '.zip':
                with zipfile.ZipFile(file_path) as archive:
                    for file in archive.namelist():
                        yield bz2.open(archive.open(file))

    return None

def slicePrice(l, n):
    try:
        x = l[n].price
    except:
        x = ""
    return(x)

def sliceSize(l, n):
    try:
        x = l[n].size
    except:
        x = ""
    return(x)

# %%
with open("../secrets.yaml", 'r') as stream:
    creds = yaml.safe_load(stream)

trading = betfairlightweight.APIClient(creds['uid'], creds['pwd'],  app_key=creds["api_key"])

listener = StreamListener(max_latency=None)

# %%
def loop_stream_markets(s, o):

    with patch("builtins.open", lambda f, _: f):

        gen = s.get_generator()

        for market_books in gen():

            timeCounter = market_books[0].publish_time

            for market_book in market_books:
                
                # Only Evaluate Thoroughbred Races
                if ((evaluate_market := filter_market(market_book)) == False):
                    break

                # Theoretical 1 second sleep on updates to minimise data
                # print(timeCounter)
                # if timeCounter is None:
                #     print('here')
                #     timeCounter = market_book.publish_time
                # else:
                #     if (market_book.publish_time - timeCounter).total_seconds() > 1:
                #         print('there')
                #         timeCounter = market_book.publish_time
                #     else:
                #         print((market_book.publish_time - timeCounter).total_seconds())
                #         continue
                                
                for runner in market_book.runners:

                    o.write(
                        "{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}\n".format(
                            market_book.market_id,
                            runner.selection_id,
                            market_book.publish_time,
                            market_book.status,
                            market_book.inplay,
                            sum([rung.size for rung in runner.ex.traded_volume]),
                            runner.last_price_traded or "",
                            slicePrice(runner.ex.available_to_back, 0),
                            slicePrice(runner.ex.available_to_lay, 0),
                            sliceSize(runner.ex.available_to_back, 0),
                            sliceSize(runner.ex.available_to_lay, 0)
                        )
                    )

                    # print(
                    #     "{}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}\n".format(
                    #         market_book.market_id,
                    #         runner.selection_id,
                    #         market_book.publish_time,
                    #         market_book.status,
                    #         market_book.inplay,
                    #         sum([rung.size for rung in runner.ex.traded_volume]),
                    #         runner.last_price_traded or "",
                    #         slicePrice(runner.ex.available_to_back, 0),
                    #         slicePrice(runner.ex.available_to_lay, 0),
                    #         sliceSize(runner.ex.available_to_back, 0),
                    #         sliceSize(runner.ex.available_to_lay, 0)
                    #     )
                    # )   

def parse_stream(dir):
    
    with open("outputs/sample.csv", "w+") as output:

        output.write("market_id,selection_id,time,market_status,inplay_status,traded_volume,ltp,best_back,best_lay,best_back_volume,best_lay_volume\n")

        for file_obj in load_markets(dir):

            stream = trading.streaming.create_historical_generator_stream(
                file_path=file_obj,
                listener=listener,
            )

            loop_stream_markets(stream, output)


parse_stream(["/media/hdd/data/betfair-stream/thoroughbred/2021_06_JunRacingAUPro.tar"])
# Out:
# /media/hdd/data/betfair-stream/thoroughbred/2021_06_JunRacingAUPro.tar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_481037/959276252.py in <module>
#      78
#      79
# ---> 80 parse_stream(["/media/hdd/data/betfair-stream/thoroughbred/2021_06_JunRacingAUPro.tar"])
#
# /tmp/ipykernel_481037/959276252.py in parse_stream(dir)
#      75             )
#      76
# ---> 77             loop_stream_markets(stream, output)
#      78
#      79
#
# /tmp/ipykernel_481037/959276252.py in loop_stream_markets(s, o)
#       5         gen = s.get_generator()
#       6
# ----> 7         for market_books in gen():
#       8
#       9             timeCounter = market_books[0].publish_time
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/betfairstream.py in _read_loop(self)
#     353                     break
#     354                 else:
# --> 355                     data = self.listener.snap()
#     356                     if data:  # can return empty list
#     357                         yield data
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/listener.py in snap(self, market_ids)
#      48         """
#      49         if self.stream_type:  # quicker than self.stream due to __len__ call
# ---> 50             return self.stream.snap(market_ids)
#      51         else:
#      52             return []
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/stream.py in snap(self, market_ids)
#      92
#      93     def snap(self, market_ids: list = None) -> list:
# ---> 94         return [
#      95             cache.create_resource(self.unique_id, snap=True)
#      96             for cache in list(self._caches.values())
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/stream.py in <listcomp>(.0)
#      93     def snap(self, market_ids: list = None) -> list:
#      94         return [
# ---> 95             cache.create_resource(self.unique_id, snap=True)
#      96             for cache in list(self._caches.values())
#      97             if market_ids is None or cache.market_id in market_ids
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/cache.py in create_resource(self, unique_id, snap)
#     308         self, unique_id: int, snap: bool = False
#     309     ) -> Union[dict, MarketBook]:
# --> 310         data = self.serialise
#     311         data["streaming_unique_id"] = unique_id
#     312         data["streaming_snap"] = snap
#
# ~/.local/lib/python3.9/site-packages/betfairlightweight/streaming/cache.py in serialise(self)
#     356             "priceLadderDefinition": self._definition_price_ladder_definition,
#     357             "keyLineDescription": self._definition_key_line_description,
# --> 358             "marketDefinition": self.market_definition,  # used in lightweight
#     359             "streaming_update": self.streaming_update,
#     360         }
#
# KeyboardInterrupt:
